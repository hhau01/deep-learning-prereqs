# %%
import matplotlib.pyplot as plt
import numpy as np

# linspace(start_pt, end_pt, num_of_pts)
x = np.linspace(0,10,10)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Time')
plt.ylabel('Some function of time')
plt.title('My cool chart')
plt.show()

# %%
# more points for smoother sin wave
x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y)
plt.show()
